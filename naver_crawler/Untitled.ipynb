# %%
import pandas as pd

# %%
pd.read_csv('newsUrlCrawl.csv')
# Out:
#                                                content  \
# 0    \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 1    \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 2    \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 3    \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 4    \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 5    \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 6    \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 7    \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 8    \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 9    \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 10   \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 11   \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 12   \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 13   \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 14   \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 15   \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# ...

# %%
df = pd.read_csv('newsUrlCrawl.csv')

# %%
int('720') // 10 + 1
# Out:
# 73

# %%
df['url'][526]
# Out:
# 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=018&aid=0000276009'

# %%
pd.read_csv('yeonhap2016.csv')
# Out:
#                                                 content  \
# 0     \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 1     \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 2     \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 3     \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 4     \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 5     \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 6     \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 7     \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 8     \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 9     \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 10    \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 11    \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 12    \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 13    \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 14    \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 15    \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# ...

# %%
pd.read_csv('edaily_2016.csv')
# Out:
#                                                 content  \
# 0     \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 1     \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 2     \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 3     \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 4     \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 5     \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 6     \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 7     \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 8     \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 9     \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 10    \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 11    \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 12    \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 13    \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 14    \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# 15    \n\t,\n\t,\n\n,\n,\n// flash 오류를 우회하기 위한 함수 추가...
# ...
